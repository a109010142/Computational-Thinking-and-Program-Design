# %% [markdown]
# <a href="https://colab.research.google.com/github/a109010142/Computational-Thinking-and-Program-Design/blob/main/%E5%91%BD%E9%81%8B%E4%B9%8B%E4%BA%BA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 我將腳本放置在最下方喔!
# ---
#
#
# 同組組員有:
#
# ---
#
#
# A109010058 新聞一甲 文及均
#
# A108050190 公廣二甲 梅宇杭
#
# A109010142 新聞一甲 羅詠馨
#
# 組長:
#
# A109010115 新聞一甲 戴柏妤

# %% [markdown]
# ## **命運之人之體驗版**

# %%
##命運之人遊戲
print("嗨！尊貴的客人你好，歡迎來到命運之人遊戲！")
print("我們WMDL遊戲公司絕對會讓你有一個很棒的遊玩體驗。")
print("在這個世界上，有很多時候命運會決定我們的人生和影響我們所做的的選擇，而此刻你將扮演一位命運之神。")
print("從他出生時即決定這個人的命運，而他也會根據你所做出的選擇做出決定!")
print("由於遊戲目前還在開發階段，您作為遊戲試玩人員我們會提供一個角色讓您體驗。")
print("您可以在遊戲中間去體驗並做出影響角色命運的決定。")
name=input("現在，請問要怎麼稱呼您呢?")
print(f"您好{name}，簡單的跟你介紹一下遊戲規則。")

##遊戲開始
print("遊戲抽取中請稍後...")
print("您的ID為:533，請輸入您的遊戲代號")
do=input("::")
if do == "533":
 print("確認完畢，命運之門已開啟為了保護您的權益請您閉上眼睛")
 print("-----即將進入遊戲世界-----")
 print("恭喜您，來到這個世界")
 print("昨晚下了一場異常大的雨，而且還伴隨著可怕的颱風。")
 print("颱風過後的今天，晴空萬里。")
 print("離城市不遠的一個村莊收到了颱風的破壞，不過損失不算嚴重。")
 print("就只有村外山腳下的那座小小古廟被颱風連根吹走了，不過並不是什麼大礙。")
 
action1=input("你今天經過了一群村民旁邊，感覺他們在議論什麼，要過去聽嗎？（是/否）")
if action1 == "是":
  print("你往村民的方向走了過去，想聽聽看他們在說什麼。")
  print(":那座廟是哪一個年代遺留下來的啊？")
  print(":好不吉利，感覺得趕快重建一座新的廟。")
  print("正當村民你一眼我一語的時候，有一個人神色慌張的跑過來。")
  print("“不得了啊，出現怪事了！怎麼了怎麼了！發生了什麼事？")
  
elif action1 == "否":
  print("你經過了那群七嘴八舌討論著什麼的村民，徑直的往被廟的方向走去，雖然那邊已經沒有什麼廟了。")
  print("不過你內心中隱約覺得那邊有著什麼東西，結果你發現原本廟的位置地上出現了一個奇怪的大洞！")
  print("這時你按耐不住內心的驚訝大喊:不得了啊，出現怪事了！")
  print("這時村民們全被你吸引了過來，怎麼了怎麼了！發生了什麼事？")
  print("大家突然聽到你大叫，都圍過來看看發生了什麼事。")
  print("那個洞口就像在吸引著你，你靠了過去然後對著洞口喊了一聲。")
  print("喂！出來！")

action2=input("你見沒有任何回音從洞裡傳上來，旁邊有一塊小石頭，要試試看丟進洞裡嗎？(是/否)")
if action2 == "是":
  print("這時候你看到對面有人向你搖手示意不要那麼做。")
  print("不過已經來不及了，你把石頭丟了下去，不過洞底卻還是沒有任何回聲傳上來。")
elif action2 == "否":
  print("你後來想想還是算了，這時候旁邊有一個年輕人卻自顧自的撿起那塊石頭丟了下去，不過洞底卻還是沒有任何回聲傳上來。")

print("這時候村民帶來了許多的樹枝和繩子圍繞著洞口做了一個簡易的圍欄，大家就先回去村莊裡了。")
print("大家也不知道該拿這個洞口怎麼辦。")
print("隨著時間一天天過去，知道這洞口的人越來越多。")
print("消息靈通的報社記者們很快就打聽到了這件事，全都匆忙的趕來村莊一探究竟。")
print("不到一時半刻，許多的科學家和學者也都聞風趕來。")
print("陸陸續續的來的人越來越多，有的人露出貪婪的目光反覆的打量這個洞口，在心裡盤算是否有利可圖。")
print("警察們則守衛在洞口周圍，深怕有人不小心靠太近掉下去。")

action3=input("你今天又經過了洞口，有一個記者向你揮手尋求幫忙，同時又有一個學者叫住了你，你會回應誰？（記者/學者）")
if action3 == "記者":
  print("那個新聞記者不知從哪裡弄來了一根很長的繩子，他叫你幫他把繩子綁在重物的另一端，小心翼翼的往下放。")
  print("繩子就這樣一尺一尺的放了下去，可是等到繩子放完卻拉不起來了!記者這時候又叫了更多的人來幫忙，不管怎麼使勁拉，都拉不起來，感覺另一端有什麼在拉扯著。")
  print("這時候繩子突然卡的一聲不知道在洞裡的什麼地方斷掉了，一堆大男人全都重心不穩摔倒在地，村民們還有記者覺得太丟臉了，也覺得這個洞太詭異了，有點邪乎，於是大夥兒決定要把洞填掉。")
elif action3 == "否":
  print("學者不知道從哪弄來了一台大功率擴音器，準備對洞裡回傳的回聲做頻率分析。")
  print("不過他一個人可做不來，還有你有過去幫忙學者。")
  print("你看他把擴音機擺弄了很久，各種聲音都試過了，可是卻連洞裡的半點聲音都沒有聽到，就算把音量開到最大限度也沒用。")
  print("學者苦苦思索著，不管眾目睽睽之下就此作罷絕對會遭人恥笑不夠專業。")
  print("他裝著鎮定、胸有成竹的樣子關掉了擴音器，對大家說到這個洞口絕對是輻射量水平很高才會影響機器，還是填掉為妙。")
  print("村民們便決定要把洞填掉。")

print("周圍那些看熱鬧的人覺得有點可惜，難道就要這樣草草收場了？")
print("正當大家要掃興而歸的時候，有個人滿頭大汗的從人群裡擠了出來。")
print(":請吧這個洞口讓給我吧，賣給我也行，我來負責幫你們填")
print("那個人就是一開始反覆打量這個洞口的商人。")
print("不過村裡的村長卻不同意，他覺得有人幫忙填洞固然是好事，不過還是應該要重建一座廟。")

action4=input("你心裡反覆思考要幫助這個商人嗎？（是/否）")
if action4 == "是":
  print("作為村里很有誠信的年輕人，你覺得有人幫忙填洞無非是壞事，於是便率先出來贊同商人的提議。")
  print("商人也藉機提出交易。")
  print(":我可以幫忙你們建造一座新的廟，更出色而且離你們村子更近的廟，怎麼樣？")
  print("村長還來不及回答，村民們卻也收到你的影響，異口同聲贊同了起來。")
  print("村長見狀也不好說什麼")
  print(":一個洞口也沒什麼特別的，就送給你吧")
  print("於是，這筆交易就在你的協助下成交了。")
elif action4 == "否":
  print("後來商人不過費盡多少口舌，都說服不了村長把洞口賣給他，只好失落的離去。")
  print("村長覺得畢竟是村子裡的事，交給一個外人來負責太奇怪了，更何況那邊本該是一座廟啊。")
  print("作為村子裡最有誠信的年輕人，村長把興建新廟的任務交給了你。")

action5=input("村長用著期待的眼神望向了你，是否要接下這個任務呢？（是/否）")
if action5 == "是":
  print("後來興建新廟的工作如火如荼的進行，可是這個洞口卻有一股魔力。")
  print("不管是什麼東西要建在洞口上面都會掉下去，而且不管填了幾次都沒有辦法填滿，連廟的地基都沒有辦法打。")
  print("後來你找了一個更適合的地方建廟，這個洞口之後也在商人不斷的交涉之下賣給了他。") 
  print("商人買下洞口後便在附近建造了一個小房子，門上掛著一個小小的招牌「填洞公司」。")
  print("在城裡的時候偶爾會聽到有人在宣傳那個洞口，似乎是新的公司口號。")
  print(":本公司擁有一個深不可測、妙不可言的神奇洞口。這絕對是處理垃圾、危險物品、核廢料、廚餘等的最佳場所。機不可失，時不再來！")
elif action5 == "否":
  print("你覺得對你來說這個任務過於重大了，而且不知道為什麼，那個洞口在你看來有點太過邪乎了。")
  print("村長也不勉強你，就轉交給了另外一位年輕人。之後聽說商人收買了那個年輕人，給了他不少好處去說服村長。")
  print("不知怎麼的，新建的廟跟一開始的位置不一樣了，不管廟建好了大家也不好說什麼。")
  print("只是現在那個洞口旁邊起了個突兀的小房子，")
  print("門上掛著一個小小的招牌「填洞公司」。")
  print("在城裡的時候偶爾會聽到有人在宣傳那個洞口，似乎是新的公司口號。")
  print("本公司擁有一個深不可測、妙不可言的神奇洞口。這絕對是處理垃圾、危險物品、核廢料、廚餘等的最佳場所。機不可失，時不再來！")

print("不久後，政府有關部門也發出了營業許可證。")
print("許多的能源開發店家也紛紛來簽訂合約。")
print("一開始村里的大家還很擔心，害怕會發生什麼事。")
print("「填洞公司」也派人對村民進行說明，這是一個非常保險的洞，丟進裡面的東西經過了上千年也不會對地面造成危害，而且來的人越多，村里就越容易繁榮啊。")
print("大家也開始漸漸放下了心來，畢竟自從這門生意開始後，村里的經濟狀況確實越來越好了。")
print("來洞口的人越來越多，每個禮拜都會有卡車源源不斷的把核廢料載過來處理。")
print("外交部和國防部也會把那些見不得光的機密文件連同保險櫃一起丟到洞裡去。")
print("失戀的人們也都把從前代表者愛情的回憶丟進洞裡，再去開始一段新的戀情。")
print("許多的犯罪分子也紛紛把一些屍體、犯罪證據、兇器扔進洞裡再逍遙法外。")
print("不管是把什麼丟進去，這個洞都會慷慨大方的一視同仁，招收不誤，似乎真的永遠也填不滿。")
print("這個洞幫過度開發，烏煙瘴氣的城市洗著各種骯髒的東西，漸漸的海洋和天空又恢復了美麗的蔚藍色。")

action6=input("距離發現這個洞已是三年的時間，想來有點感慨，要去洞口那邊看看嗎？（是/否）")
if action6 == "是":
  print("你仔細了端詳一下洞口，他還是跟當初的一樣，卻又顯得哪裡有點不一樣。")
  print("你由衷的感謝這個任勞任怨的洞口。")
  print("後來你轉身離去，望著天空讚嘆世界變得越來越美好了！")
  print(":喂！出來！，聽到聲音後你戛然而止，思索著剛剛的那個聲音，感覺好像在哪裡聽過。")
  print("望了望附近確定沒人，想著可能是天氣太熱了有點頭暈產生錯覺。")
  print("決定要回家好好休息一番，突然剛剛發出聲音的地方飛來一塊是天氣，從你面前一閃而過掉在了地上。")
  print("當然，那快微不足道的石頭根本沒引起你的注意。")
  print("此刻的你瞇著眼望向天空，望向這個美好的世界。THE END")
elif action6 == "否":
  print("這時候的你已經成家立業，想想等等兒子要回來了，還是算了吧。")
  print("正想到這兒子回來了，他今天看起來特別開心。")
  print("告訴我他今天在學校碰到的趣事，還有他又去洞口完了。")
  print("真不知道他也對那個洞口深深著迷是遺傳到誰。")
  print("他說今天又去那邊探望那個偉大的洞口了，還聽到有人叫了他，不管轉頭卻又沒有看到人。")
  print("不過你不知道的是，兒子聽到的聲音。")
  print("喂！出來")
  print("你也沒有注意到，兒子從那邊帶回了一塊微不足道的小石頭。THE END")
print("--------蹦 時間已到--------")
print(f"醒醒{name}，今日份體驗已結束")
print("遊玩時間已經到了，不知道你對命運遊戲的劇情還滿意嗎？")
print("希望你剛剛有一個非常愉快的遊玩體驗，結束之後是否對你的人生觀有著什麼改變呢。")
print("你的回饋將會是我們的進步，那下次記得再回來玩喔！感謝你！")
# Out:
# 嗨！尊貴的客人你好，歡迎來到命運之人遊戲！
# 我們WMDL遊戲公司絕對會讓你有一個很棒的遊玩體驗。
# 在這個世界上，有很多時候命運會決定我們的人生和影響我們所做的的選擇，而此刻你將扮演一位命運之神。
# 從他出生時即決定這個人的命運，而他也會根據你所做出的選擇做出決定!
# 由於遊戲目前還在開發階段，您作為遊戲試玩人員我們會提供一個角色讓您體驗。
# 您可以在遊戲中間去體驗並做出影響角色命運的決定。
# 現在，請問要怎麼稱呼您呢?獅子
# 您好獅子，簡單的跟你介紹一下遊戲規則。
# 遊戲抽取中請稍後...
# 您的ID為:533，請輸入您的遊戲代號
# ::533
# 確認完畢，命運之門已開啟為了保護您的權益請您閉上眼睛
# -----即將進入遊戲世界-----
# 恭喜您，來到這個世界
# 昨晚下了一場異常大的雨，而且還伴隨著可怕的颱風。
# 颱風過後的今天，晴空萬里。
# 離城市不遠的一個村莊收到了颱風的破壞，不過損失不算嚴重。
# 就只有村外山腳下的那座小小古廟被颱風連根吹走了，不過並不是什麼大礙。
# 你今天經過了一群村民旁邊，感覺他們在議論什麼，要過去聽嗎？（是/否）是
# 你往村民的方向走了過去，想聽聽看他們在說什麼。
# :那座廟是哪一個年代遺留下來的啊？
# :好不吉利，感覺得趕快重建一座新的廟。
# 正當村民你一眼我一語的時候，有一個人神色慌張的跑過來。
# “不得了啊，出現怪事了！怎麼了怎麼了！發生了什麼事？
# 你見沒有任何回音從洞裡傳上來，旁邊有一塊小石頭，要試試看丟進洞裡嗎？(是/否)否
# 你後來想想還是算了，這時候旁邊有一個年輕人卻自顧自的撿起那塊石頭丟了下去，不過洞底卻還是沒有任何回聲傳上來。
# 這時候村民帶來了許多的樹枝和繩子圍繞著洞口做了一個簡易的圍欄，大家就先回去村莊裡了。
# 大家也不知道該拿這個洞口怎麼辦。
# 隨著時間一天天過去，知道這洞口的人越來越多。
# 消息靈通的報社記者們很快就打聽到了這件事，全都匆忙的趕來村莊一探究竟。
# 不到一時半刻，許多的科學家和學者也都聞風趕來。
# 陸陸續續的來的人越來越多，有的人露出貪婪的目光反覆的打量這個洞口，在心裡盤算是否有利可圖。
# 警察們則守衛在洞口周圍，深怕有人不小心靠太近掉下去。
# ...

# %% [markdown]
# # **體驗版的腳本**

# %% [markdown]
# 碰上離奇洞口的年輕人
#
# 昨晚下了一場異常大的雨，而且還伴隨著可怕的颱風。
# 颱風過後的今天，晴空萬里。
# 離城市不遠的一個村莊收到了颱風的破壞，不過損失不算嚴重。
# 就只有村外山腳下的那座小小古廟被颱風連根吹走了，不過並不是什麼大礙。
# 你今天經過了一群村民旁邊，感覺他們在議論什麼，要過去聽嗎？（YES/NO）
# 【YES】
# 【NO】
#
# 選擇了YES
# 你往村民的方向走了過去，想聽聽看他們在說什麼。
# “那座廟是哪一個年代遺留下來的啊？”
# “好不吉利，感覺得趕快重建一座新的廟。”
# 正當村民你一眼我一語的時候，有一個人神色慌張的跑過來。
# “不得了啊，出現怪事了！”
# “怎麼了怎麼了！發生了什麼事？”
# “大家快過來看啊，這個洞是怎麼回事！”
# 這時候村民們往洞的方向跑去，要跟過去看嗎？（YES/NO）
#
# YES
# 這時一個年輕人對著洞裡用力的大叫了一聲。
# ‘’喂！出來！‘’
# 他見沒有任何回音從洞裡傳上來，便準備撿了一塊小石頭準備丟進洞裡。
# 你感覺這樣做並不妥，要阻止他嗎？（YES/NO）
#
#
#
# YES
# 你擺著雙手，開口正準備勸阻年輕人不要那麼做。
# 但是卻來不及了，他搶先一步把石頭丟了下去，不過洞底卻沒有任何回聲傳上來。
# NO
# 你雖然覺得不妥，不過好像也沒有阻止年輕人的理由。
# 年輕人把石頭丟了下去，不過洞底卻沒有任何回聲傳上來。
#
# NO
# 後來等到你好奇再過去的時候那邊已經沒人了。
# 你自討沒趣的看著洞口。
# 突然大叫了一聲。
# “喂！出來！”
# 你看著這個深不見底的洞口若有所思，你把脚邊的石頭也順勢踢了下去。
# 那閒小廟一直是你很喜歡的地方，突然就沒了，難過的情緒也無從安放。
#
# 選擇了NO
# 你經過了那群七嘴八舌討論著什麼的村民，徑直的往被廟的方向走去，雖然那邊已經沒有什麼廟了。
# 不過你內心中隱約覺得那邊有著什麼東西。
# 結果你發現原本廟的位置地上出現了一個奇怪的大洞！
# 這時你按耐不住內心的驚訝大喊
# “不得了啊，出現怪事了！’’
# 這時村民們全被你吸引了過來
# “怎麼了怎麼了！發生了什麼事？’’
# 大家突然聽到你大叫，都圍過來看看發生了什麼事。
# 那個洞口就像在吸引著你，你靠了過去然後對著洞口喊了一聲。
# ‘’喂！出來！‘’
# 你見沒有任何回音從洞裡傳上來，旁邊有一塊小石頭，要試試看丟進洞裡嗎？（YES/NO）
#
# YES
# 這時候你看到對面有人向你搖手示意不要那麼做。
# 不過已經來不及了，你把石頭丟了下去，不過洞底卻還是沒有任何回聲傳上來。
#
# NO
# 你後來想想還是算了，這時候旁邊有一個年輕人卻自顧自的撿起那塊石頭丟了下去，不過洞底卻還是沒有任何回聲傳上來。
#
# 這時候村民帶來了許多的樹枝和繩子圍繞著洞口做了一個簡易的圍欄，大家就先回去村莊裡了。
# 大家也不知道該拿這個洞口怎麼辦。
# 隨著時間一天天過去，知道這洞口的人越來越多。
# 消息靈通的報社記者們很快就打聽到了這件事，全都匆忙的趕來村莊一探究竟。
# 不到一時半刻，許多的科學家和學者也都聞風趕來。
# 陸陸續續的來的人越來越多，有的人露出貪婪的目光反覆的打量這個洞口，在心裡盤算是否有利可圖。
# 警察們則守衛在洞口周圍，深怕有人不小心靠太近掉下去。
# 你今天又經過了洞口，有一個記者向你揮手尋求幫忙，同時又有一個學者叫住了你，你會回應誰？（1:記者 / 2:學者）
#
# 選擇了1
# 那個新聞記者不知從哪裡弄來了一根很長的繩子。
# 他叫你幫他把繩子綁在重物的另一端，小心翼翼的往下放。
# 繩子就這樣一尺一尺的放了下去，可是等到繩子放完卻拉不起來了。
# 記者這時候又叫了更多的人來幫忙，不管怎麼使勁拉，都拉不起來，感覺另一端有什麼在拉扯著。
# 這時候繩子突然卡的一聲不知道在洞裡的什麼地方斷掉了，一堆大男人全都重心不穩摔倒在地。
# 村民們還有記者覺得太丟臉了，也覺得這個洞太詭異了，有點邪乎。
# 大夥兒決定要把洞填掉。
#
# 選擇了2
# 學者不知道從哪弄來了一台大功率擴音器，準備對洞裡回傳的回聲做頻率分析。
# 不過他一個人可做不來，還有你有過去幫忙學者。
# 你看他把擴音機擺弄了很久，各種聲音都試過了，可是卻連洞裡的半點聲音都沒有聽到，就算把音量開到最大限度也沒用。
# 學者苦苦思索著，不管眾目睽睽之下就此作罷絕對會遭人恥笑不夠專業。
# 他裝著鎮定、胸有成竹的樣子關掉了擴音器，對大家說到這個洞口絕對是輻射量水平很高才會影響機器，還是填掉為妙。
# 村民們便決定要把洞填掉。
#
# 周圍那些看熱鬧的人覺得有點可惜，難道就要這樣草草收場了？
# 正當大家要掃興而歸的時候，有個人滿頭大汗的從人群裡擠了出來。
# ‘’請吧這個洞口讓給我吧，賣給我也行，我來負責幫你們填‘’
# 那個人就是一開始反覆打量這個洞口的商人。
# 不過村裡的村長卻不同意，他覺得有人幫忙填洞固然是好事，不過還是應該要重建一座廟。
# 你心裡反覆思考要幫助這個商人嗎？（YES/NO）
#
# 選擇了YES
# 作為村里很有誠信的年輕人，你覺得有人幫忙填洞無非是壞事，於是便率先出來贊同商人的提議。
# 商人也藉機提出交易。
# “我可以幫忙你們建造一座新的廟，更出色而且離你們村子更近的廟，怎麼樣？”
# 村長還來不及回答，村民們卻也收到你的影響，異口同聲贊同了起來。
# 村長見狀也不好說什麼
# ‘’一個洞口也沒什麼特別的，就送給你吧‘’
# 於是，這筆交易就在你的協助下成交了。
# 商人為了答謝你也問你是否要到他旗下工作，將會有更好的福利，你的回答是？（YES/NO）
#
# YES
# 商人後來履行了自己的承諾，在離村莊更近的地方建起一個新廟來了。
# 後來商人在這個洞的附加建起了一個小房子，門上掛著一個小小的招牌「填洞公司」。
# 商人委任了你來當「填洞公司」的負責人。
# 接著他便派人開始到各處奔走，用各種方法宣傳。
# ‘’本公司擁有一個深不可測、妙不可言的神奇洞口。這絕對是處理垃圾、危險物品、核廢料、廚餘等的最佳場所。機不可失，時不再來！‘’
#
# NO
# 雖然你很感激商人的邀約，不過你畢竟對村莊還是很有愛，所以婉拒了商人的邀約。
# 你也參與了興建新廟的工作，每天都忙得不亦樂乎。
# 偶爾你還是會特地經過那個洞口，好奇的往那邊看去，想想村子也因為這個洞口的出現熱鬧了不少。
# 不知什麼時候，那邊默默的起了一個小房子，門上掛著一個小小的招牌「填洞公司」。
# 後來開始會聽到某處在宣傳那個洞口，似乎是新的公司口號。
# ‘’本公司擁有一個深不可測、妙不可言的神奇洞口。這絕對是處理垃圾、危險物品、核廢料、廚餘等的最佳場所。機不可失，時不再來！‘’
#
# 選擇了NO
# 後來商人不過費盡多少口舌，都說服不了村長把洞口賣給他，只好失落的離去。
# 村長覺得畢竟是村子裡的事，交給一個外人來負責太奇怪了，更何況那邊本該是一座廟啊。
# 作為村子裡最有誠信的年輕人，村長把興建新廟的任務交給了你。
# 村長用著期待的眼神望向了你，是否要接下這個任務呢？（YES/NO）
#
# Yes
# 後來興建新廟的工作如火如荼的進行，可是這個洞口卻有一股魔力。
# 不管是什麼東西要建在洞口上面都會掉下去，而且不管填了幾次都沒有辦法填滿，連廟的地基都沒有辦法打。
# 後來你找了一個更適合的地方建廟，這個洞口之後也在商人不斷的交涉之下賣給了他。
# 商人買下洞口後便在附近建造了一個小房子，門上掛著一個小小的招牌「填洞公司」。
# 在城裡的時候偶爾會聽到有人在宣傳那個洞口，似乎是新的公司口號。
# ‘’本公司擁有一個深不可測、妙不可言的神奇洞口。這絕對是處理垃圾、危險物品、核廢料、廚餘等的最佳場所。機不可失，時不再來！‘’
#
# NO
# 你覺得對你來說這個任務過於重大了，而且不知道為什麼，那個洞口在你看來有點太過邪乎了。
# 村長也不勉強你，就轉交給了另外一位年輕人。
# 之後聽說商人收買了那個年輕人，給了他不少好處去說服村長。
# 不知怎麼的，新建的廟跟一開始的位置不一樣了，不管廟建好了大家也不好說什麼。
# 只是現在那個洞口旁邊起了個突兀的小房子，
# 門上掛著一個小小的招牌「填洞公司」。
# 在城裡的時候偶爾會聽到有人在宣傳那個洞口，似乎是新的公司口號。
# ‘’本公司擁有一個深不可測、妙不可言的神奇洞口。這絕對是處理垃圾、危險物品、核廢料、廚餘等的最佳場所。機不可失，時不再來！‘’
#
# 不久後，政府有關部門也發出了營業許可證。
# 許多的能源開發店家也紛紛來簽訂合約。
# 一開始村里的大家還很擔心，害怕會發生什麼事。
# 「填洞公司」也派人對村民進行說明，這是一個非常保險的洞，丟進裡面的東西經過了上千年也不會對地面造成危害，而且來的人越多，村里就越容易繁榮啊。
# 大家也開始漸漸放下了心來，畢竟自從這門生意開始後，村里的經濟狀況確實越來越好了。
#
# 來洞口的人越來越多，每個禮拜都會有卡車源源不斷的把核廢料載過來處理。
# 外交部和國防部也會把那些見不得光的機密文件連同保險櫃一起丟到洞裡去。
# 失戀的人們也都把從前代表者愛情的回憶丟進洞裡，再去開始一段新的戀情。
# 許多的犯罪分子也紛紛把一些屍體、犯罪證據、兇器扔進洞裡再逍遙法外。
# 不管是把什麼丟進去，這個洞都會慷慨大方的一視同仁，招收不誤，似乎真的永遠也填不滿。
# 這個洞幫過度開發，烏煙瘴氣的城市洗著各種骯髒的東西，漸漸的海洋和天空又恢復了美麗的蔚藍色。
# 今天距離發現這個洞已是三年的時間，想來有點感慨，要去洞口那邊看看嗎？（YES/NO）
#
# 選擇了YES
# 你仔細了端詳一下洞口，他還是跟當初的一樣，卻又顯得哪裡有點不一樣。
# 你由衷的感謝這個任勞任怨的洞口。
# 後來你轉身離去，望著天空讚嘆世界變得越來越美好了！
# ‘’喂！出來！‘’
# 你戛然而止，思索著剛剛的那個聲音，感覺好像在哪裡聽過。
# 望了望附近確定沒人，想著可能是天氣太熱了有點頭暈產生錯覺。
# 決定要回家好好休息一番，突然剛剛發出聲音的地方飛來一塊是天氣，從你面前一閃而過掉在了地上。
# 當然，那快微不足道的石頭根本沒引起你的注意。
# 此刻的你瞇著眼望向天空，望向這個美好的世界。THE END
#
#
#
# 選擇了NO
# 這時候的你已經成家立業，想想等等兒子要回來了，還是算了吧。
# 正想到這兒子回來了，他今天看起來特別開心。
# 告訴我他今天在學校碰到的趣事，還有他又去洞口完了。
# 真不知道他也對那個洞口深深著迷是遺傳到誰。
# 他說今天又去那邊探望那個偉大的洞口了，還聽到有人叫了他，不管轉頭卻又沒有看到人。
# 不過你不知道的是，兒子聽到的聲音。
# ‘’喂！出來‘’
# 你也沒有注意到，兒子從那邊帶回了一塊微不足道的小石頭。THE END
#
#
# 喂喂！｛name｝醒來嘍！
# 遊玩時間已經到了，不知道你對命運遊戲的劇情還滿意嗎？
# 希望你剛剛有一個非常愉快的遊玩體驗，結束之後是否對你的人生觀有著什麼改變呢。
# 你的回饋將會是我們的進步，那下次記得再回來玩喔！感謝你！
